# %% [markdown]
# <a href="https://colab.research.google.com/github/DavorJordacevic/WeatherDataWWO/blob/master/weather_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wwo-hist

# %%
import os
import requests

# %%
from wwo_hist import retrieve_hist_data

# %%
frequency = 1
start_date = '01-JAN-2019'
end_date = '31-DEC-2019'
api_key = '________________'
location_list = ['belgrade']
hist_weather_data = retrieve_hist_data(api_key,
                                      location_list,
                                      start_date,
                                      end_date,
                                      frequency,
                                      location_label = False,
                                      export_csv = True,
                                      store_df = True)
# Out:
# Retrieving weather data for belgrade
#
#
# Currently retrieving data for belgrade: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.182695
# Currently retrieving data for belgrade: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:02.151582
# Currently retrieving data for belgrade: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.399347
# Currently retrieving data for belgrade: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.423388
# Currently retrieving data for belgrade: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.463169
# Currently retrieving data for belgrade: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.516676
# Currently retrieving data for belgrade: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.644917
# Currently retrieving data for belgrade: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.746646
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("belgrade.csv") 

df.head()
# Out:
#              date_time  maxtempC  ...  windspeedKmph  location
# 0  2019-01-01 00:00:00         5  ...             12  belgrade
# 1  2019-01-01 01:00:00         5  ...             11  belgrade
# 2  2019-01-01 02:00:00         5  ...             11  belgrade
# 3  2019-01-01 03:00:00         5  ...             10  belgrade
# 4  2019-01-01 04:00:00         5  ...              9  belgrade
#
# [5 rows x 25 columns]

# %%
df.tail()
# Out:
#                 date_time  maxtempC  ...  windspeedKmph  location
# 8755  2019-12-31 19:00:00         1  ...              9  belgrade
# 8756  2019-12-31 20:00:00         1  ...             11  belgrade
# 8757  2019-12-31 21:00:00         1  ...             13  belgrade
# 8758  2019-12-31 22:00:00         1  ...             13  belgrade
# 8759  2019-12-31 23:00:00         1  ...             14  belgrade
#
# [5 rows x 25 columns]

# %% [markdown]
# ---
